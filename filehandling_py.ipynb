# %%
file = open("/content/drive/MyDrive/Colab Notebooks/mymath.py",'w')
content = file.write("hello python")
print(content)
file.close()
# Out:
# 12

# %%
file = open("/content/drive/MyDrive/Colab Notebooks/mymath.py",'r')
content = file.read()
print(content)
file.close()
# Out:
# {"nbformat":4,"nbformat_minor":0,"metadata":{"colab":{"provenance":[],"authorship_tag":"ABX9TyMOSXE8U6GGwEDsyuVmzuLZ"},"kernelspec":{"name":"python3","display_name":"Python 3"},"language_info":{"name":"python"}},"cells":[{"cell_type":"code","execution_count":null,"metadata":{"id":"drNvhSx8e-Or"},"outputs":[],"source":["def add(x, y):\n","    return x + y\n","\n","def subtract(x, y):\n","    return x - y\n","\n","def multiply(x, y):\n","    return x * y"]}]}

# %%
file = open("/content/drive/MyDrive/jpg image.pdf",'rb')
nt = file.read()
print(content)
file.close()
# Out:
# b'%PDF-1.4\n%\xe2\xe3\xcf\xd3\n1 0 obj\n<</Filter/FlateDecode/Alternate/DeviceRGB/Length 251/N 3>>stream\nx\x9cc``<\xc1\x00\x04,\x06\x0c\x0c\xb9y%EA\xeeN\n\x11\x91Q\n\xec\x0f\x18\x18\x81\x10\x0c\x12\x93\x8b\x0b\x18p\x03\xa0\xaao\xd7 j/\xeb\xe2Q\x87\x0bp\xa6\xa4\x16\'\x03\xe9\x0f@\xacR\x04\xb4\x1ch\xa4\x08\x90-\x92\x0eak\x80\xd8I\x10\xb6\r\x88]^RP\x02d\x07\x80\xd8E!A\xce@v\n\x90\xad\x91\x8e\xc4NBb\'\x17\x14\x81\xd4\xf7\x00\xd96\xb99\xa5\xc9\x08w3\xf0\xa4\xe6\x85\x06\x03i\x0e \x96a(f\x08bpgp\x02\xf9\x1f\xa2$\x7f\x11\x03\x83\xc5W\x06\x06\xe6\t\x08\xb1\xa4\x99\x0c\x0c\xdb[\x19\x18$n!\xc4T\x1600\xf0\xb700l;\x8f\x10C\x84IAbQ"X\x88\x05\x88\x99\xd2\xd2\x18\x18>-g`\xe0\x8dd`\x10\xbe\xc0\xc0\xc0\x15\r\x0b\x08\x1cnS\x00\xbb\xcd\x9d!\x1f\x08\xd3\x19r\x18R\x81"\x9e\x0cy\x0c\xc9\x0cz@\x96\x11\x83\x01\x83!\x83\x19\x00\xa6\xd6??\nendstream\nendobj\n2 0 obj\n<</ColorSpace[/ICCBased 1 0 R]/Subtype/Image/Height 1090/Filter/DCTDecode/Type/XObject/Width 805/BitsPerComponent 8/Length 79899>>stream\n\xff\x
# ...

# %%
file = open("/content/drive/MyDrive/Colab Notebooks/mymath.py",'a')
content = file.write("hello python")
print(content)
file.close()
# Out:
# 12

# %%
file = open("/content/drive/MyDrive/jpg image.pdf",'wb')
content = file.write(b"ghgh")
print(content)
file.close()
# Out:
# 4

# %%
with open("/content/drive/MyDrive/jpg image.pdf",'wb') as file:
  content = file.write(b"ghgh")
print(content)
file.close()
# Out:
# 4

# %%
with open("/content/drive/MyDrive/jpg image.pdf",'rb') as file:
  content = file.read()
print(content)
file.close()
# Out:
# b'ghgh'

# %%
with open("/content/drive/MyDrive/jpg image.pdf",'ab') as file:
  content = file.write(b"ghgh")
print(content)
file.close()
# Out:
# 4

# %%
file = open("/content/drive/MyDrive/Colab Notebooks/mymath.py",'a')
content = file.write("hello python")
print(content)
file.close()
# Out:
# 12
